# %%
def self_esteem(_idx, _data):

    _scope = {
        "self_esteem": None
    }

    #self_esteem: bins variable 1: high, 0: low 
    # Allergist / Immunologist: range(0, 36, 1), 59
    if  _data[_idx]["speciality"] == (1, "Allergist / Immunologist"):
        if _idx in range(0, 21):
            _scope["self_esteem"]=1
        else:
            _scope["self_esteem"]=0

    # Anesthesiologist:  range(37, 493, 1)      
      #self_esteem: bins variable 1: high, 0: low ,54%
    elif  _data[_idx]["speciality"] == (2, "Anesthesiologist"):
        if _idx in range(37, 283):
            _scope[" self_esteem"]=1
        else:
            _scope["self_esteem"]=0

       
            
    # Dermatologist: range(494, 616)
    
     #self_esteem: bins variable 1: high, 0: low ,56%
    elif  _data[_idx]["speciality"] == (3, "Dermatologist"):
        if _idx in range(494, 562):
            _scope["self_esteem"]=1
        else:
            _scope["self_esteem"]=0        
              
    # Emergency Doctor: range(617,1095)
            
       #self_esteem: bins variable 1: high, 0: low ,58%
    elif  _data[_idx]["speciality"] == (4, "Emergency Doctor"):
        if _idx in range(617, 894):
            _scope["self_esteem"]=1
        else:
            _scope["self_esteem"]=0  
    
    # Family Doctor: range(1096,2216)
    
      #self_esteem: bins variable 1: high, 0: low ,51%
      
    elif  _data[_idx]["speciality"] == (5, "Family Doctor"):
        if _idx in range(1096, 1667):
            _scope["self_esteem"]=1
        else:
            _scope["self_esteem"]=0 
    
   # Internist:  range(2217,4289)
   
      #self_esteem: bins variable 1: high, 0: low ,50%
    
    elif  _data[_idx]["speciality"] == (6, "Internist"):
        if _idx in range(2217, 3253):
            _scope["self_esteem"]=1
        else:
            _scope["self_esteem"]=0 
                
    # Neurological Surgeon: range(4290,4349)

      #self_esteem: bins variable 1: high, 0: low ,55%
    elif  _data[_idx]["speciality"] == (7, "Neurological Surgeon"):
        if _idx in range(4290, 4322):
            _scope["self_esteem"]=1
        else:
            _scope["self_esteem"]=0
            
    # Obstetrician / Gynecologist: 5.17% of a population of 8000 = 414
    
            
        #self_esteem: bins variable 1: high, 0: low ,55%
    elif  _data[_idx]["speciality"] == (8, "Obstetrician / Gynecologist"):
        if _idx in range(4350, 4578):
            _scope["self_esteem"]=1
        else:
            _scope["self_esteem"]=0
            
   # Orthopedic Surgeon: range(4765,5026)
    
        #self_esteem: bins variable 1: high, 0: low ,66%
    elif  _data[_idx]["speciality"] == (9, "Orthopedic Surgeon"):
        if _idx in range(4765, 4937):
            _scope["self_esteem"]=1
        else:
            _scope["self_esteem"]=0 
                
  # Otolaryngologist: range(5027,5130)
        
     #self_esteem: bins variable 1: high, 0: low ,67%
    elif   _data[_idx]["speciality"] == (10, "Otolaryngologist"):
        if _idx in range(5027, 5096):
            _scope["self_esteem"]=1
        else:
            _scope["self_esteem"]=0 
 
  # Pathologist: range(5131,5299)
    
    elif   _data[_idx]["speciality"] == (11, "Pathologist"):
        if _idx in range(5131, 5217):
            _scope["self_esteem"]=1
        else:
            _scope["self_esteem"]=0  
                
    # Pediatrician:range(5300,6055) 
    
        #self_esteem: bins variable 1: high, 0: low ,53%
    elif  _data[_idx]["speciality"] == (12, "Pediatrician"):
        if _idx in range(5300, 5700):
            _scope["self_esteem"]=1
        else:
            _scope["self_esteem"]=0  
            
   # Plastic Surgeons: range(6056,6099)
   
         #self_esteem: bins variable 1: high, 0: low ,73%
    elif  _data[_idx]["speciality"] == (13, "Plastic Surgeons"):
        if _idx in range(6056, 6087):
             _scope["self_esteem"]=1
        else:
             _scope["self_esteem"]=0 
            
     # Psychiatrist/Neurologist: range(6100,6735)
    
      #self_esteem: bins variable 1: high, 0: low ,53%
    elif  _data[_idx]["speciality"] == (14, "Psychiatrist/Neurologist"):
        if _idx in range(6100, 6437):
            _scope["self_esteem"]=1
        else:
            _scope["self_esteem"]=0 
                
   # Radiologist: range(6736,7147)   
    
     #self_esteem: bins variable 1: high, 0: low ,57%
    elif  _data[_idx]["speciality"] == (15, "Radiologist"):
        if _idx in range(6736, 6970):
            _scope["self_esteem"]=1
        else:
            _scope["self_esteem"]=0 
            
  # Surgeons: range(7148,7488)
    
      #self_esteem: bins variable 1: high, 0: low ,63%
    elif  _data[_idx]["speciality"] == (16, "Surgeons"):
        if _idx in range(7148, 7362):
            _scope["self_esteem"]=1
        else:
            _scope["self_esteem"]=0 
               
   # Urologist: range(7489,7592)
            
        #self_esteem: bins variable 1: high, 0: low ,68%
    elif  _data[_idx]["speciality"] == (17, "Urologist"):
        if _idx in range(7489, 7559):
            _scope["self_esteem"]=1
        else:
            _scope["self_esteem"]=0 

    #Optometrist: 67%
    
    else:
        if _idx in range(7593, 7893):
            _scope["self_esteem"]=1
        else:
            _scope["self_esteem"]=0 


    result = _.assign(_data[_idx], {"self_esteem":_scope["self_esteem"]})
    return result

""""
# audit
se = _.filter_(doctors, lambda  _item: _item['self_esteem'] == 1)
print(len(se))
3209 !! wrong
""""
